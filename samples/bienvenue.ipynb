// %% [markdown]
// # Bienvenue sur le Kotlin de l'EB03
//
// Ce notebook tourne dans votre navigateur, sans rien installer. Modifiez les cellules et executez-les avec `Shift+Entree`.

// %%
class Personnage(val nom: String, var pv: Int)

val heros = Personnage("Aldric", 20)
println("${heros.nom} : ${heros.pv} PV")
